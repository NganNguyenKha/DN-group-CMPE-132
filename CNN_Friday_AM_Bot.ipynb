# %% [markdown]
# <a href="https://colab.research.google.com/github/NganNguyenKha/DN-group-CMPE-132/blob/CNN/CNN_Friday_AM_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #!/usr/bin/env python
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import sklearn.preprocessing
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE

# %%
import missingno

# %%
train_data = pd.read_csv('/content/Friday-WorkingHours-Morning.pcap_ISCX.train.csv')
test_data = pd.read_csv('/content/Friday-WorkingHours-Morning.pcap_ISCX.test.csv')

# %%
train_data_df = pd.DataFrame(train_data)
print(train_data_df.shape)
# Out:
# (152825, 79)

# %%
#train_data_df = train_data_df[['Duration','protocol_type', 'Service', 'Srv serror rate', 'Flag','src_bytes','dst_bytes', 'Dst host serror rate', 'Dst host srv serror rate', 'Dst host same src port rate', 'Label','Serror rate','Count','Dst host count']]
train_data_df = train_data_df[[' Destination Port', ' Flow Duration', ' Total Fwd Packets', 'Total Length of Fwd Packets', ' Label']]

# %%
train_data_df.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      152825.000000    1.528250e+05       152825.000000
# mean         6599.041793    1.172502e+07           15.592115
# std         16549.025911    3.071862e+07         1227.244462
# min             0.000000   -1.200000e+01            1.000000
# 25%            53.000000    2.000000e+02            2.000000
# 50%            80.000000    3.119500e+04            2.000000
# 75%           443.000000    3.644900e+05            4.000000
# max         64948.000000    1.199999e+08       207964.000000
#
#        Total Length of Fwd Packets
# count                 1.528250e+05
# mean                  6.191988e+02
# std                   8.798755e+03
# min                   0.000000e+00
# 25%                   4.200000e+01
# 50%                   7.000000e+01
# 75%                   1.520000e+02
# max                   1.235152e+06

# %%
train_data_df = train_data_df.dropna()

# %%
print(train_data_df.columns)
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        'Total Length of Fwd Packets', ' Label'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
def encodify(dataframe, feature):
    encoder = LabelEncoder()
    encoder.fit(dataframe[feature])
    encoded_feature = encoder.transform(dataframe[feature])
    dataframe[feature] = encoded_feature

# %%
discrete_feature_l = [' Destination Port', ' Flow Duration', ' Total Fwd Packets', 'Total Length of Fwd Packets']
for feature in discrete_feature_l:
    encodify(train_data_df, feature)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f23ac0a2e2cd> in <cell line: 0>()
#       1 discrete_feature_l = [' Destination Port', ' Flow Duration', ' Total Fwd Packets', 'Total Length of Fwd Packets']
#       2 for feature in discrete_feature_l:
# ----> 3     encodify(train_data_df, feature)
#
# NameError: name 'encodify' is not defined

# %% [markdown]
# # train-to-test split

# %%
eighty_cut_n = math.ceil(train_data_df.shape[0] * 0.8)
print(eighty_cut_n)
# Out:
# 122260

# %%
train_data_df.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0               1856           67022                  31
# 1                 12           67021                  31
# 2                  0           67165                 345
# 3               3475           26337                  21
# 4                  0           16122                   3
#
#    Total Length of Fwd Packets   Label
# 0                         6448  BENIGN
# 1                         6448  BENIGN
# 2                            0  BENIGN
# 3                          616  BENIGN
# 4                            0  BENIGN

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler = StandardScaler()

# %%
X = train_data_df.loc[:, [' Destination Port', ' Flow Duration', ' Total Fwd Packets', 'Total Length of Fwd Packets']]
y = train_data_df.loc[:, ' Label']

# %%
X=Scaler.fit_transform(X)

# %%
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
from sklearn.model_selection import train_test_split

# %%
train_data.shape
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 420)

# %%
X_train.shape
# Out:
# (241968, 4)

# %%
X_test.shape
# Out:
# (60492, 4)

# %%
y_train.value_counts()
# Out:
#  Label
# BENIGN    121236
# Bot       120732
# Name: count, dtype: int64

# %%
label_l = ['1', '-1','-2']
classes = pd.value_counts(y_train, sort = True)
classes.plot(kind = 'bar', rot = 0, color = "green")
plt.title("Network Traffic Distribution (Training Set)")
plt.xticks(range(3), label_l)
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# <ipython-input-24-baa50a2511b9>:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   classes = pd.value_counts(y_train, sort = True)
# Text(0, 0.5, 'Frequency')

# %%
y_test.value_counts()
# Out:
#  Label
# Bot       30498
# BENIGN    29994
# Name: count, dtype: int64

# %%
labels = ['1', '-1','-2']
classes = pd.value_counts(y_test , sort = True)
classes.plot(kind = 'bar', rot = 0, color = "pink")
plt.title("Network Traffic Distribution (Testing Set)")
plt.xticks(range(3), labels)
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# <ipython-input-26-2b5c4e26709d>:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   classes = pd.value_counts(y_test , sort = True)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Modeling

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %%
clf = MLPClassifier(solver='adam', alpha=1e-5,

                    hidden_layer_sizes=(5, 2), random_state=1, max_iter=1000)

# %%
clf.fit(X, y)
# Out:
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=(5, 2), max_iter=1000,
#               random_state=1)

# %%
pred_test_y = clf.predict(X_test)
print(pred_test_y)
# Out:
# ['BENIGN' 'BENIGN' 'BENIGN' ... 'Bot' 'BENIGN' 'Bot']

# %%
accuracy_score(y_test, pred_test_y)
# Out:
# 0.9759637638034782

# %%
confusion_matrix(y_test, pred_test_y)
# Out:
# array([[28553,  1441],
#        [   13, 30485]])

# %%
tn, fp, fn, tp = confusion_matrix(y_test, pred_test_y).ravel()
print(f"accuracy is {(tp +tn)/(tn+fp+fn+tp)}")
print(f"precision is {tp / (tp + fp)}")
print(f"recall is {tp / (tp + fn)}")
# Out:
# accuracy is 0.9759637638034782
# precision is 0.9548643738645618
# recall is 0.9995737425404945

# %% [markdown]
# ## SVM

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
nslkdd_svm_clf = svm.SVC(kernel = 'rbf').fit(X_train, y_train)

# %%
pred_test_y = nslkdd_svm_clf.predict(X_test)
print(pred_test_y)
# Out:
# ['BENIGN' 'BENIGN' 'BENIGN' ... 'Bot' 'BENIGN' 'Bot']

# %%
accuracy_score(y_test, pred_test_y)
# Out:
# 0.9792203927792105

# %%
confusion_matrix(y_test, pred_test_y)
# Out:
# array([[28754,  1240],
#        [   17, 30481]])

# %%
tn, fp, fn, tp = confusion_matrix(y_test, pred_test_y).ravel()
print(f"accuracy is {(tp +tn)/(tn+fp+fn+tp)}")
print(f"precision is {tp / (tp + fp)}")
print(f"recall is {tp / (tp + fn)}")
# Out:
# accuracy is 0.9792203927792105
# precision is 0.9609091768859745
# recall is 0.9994425863991081

# %%
f1_score(y_test, pred_test_y, average='macro')
# Out:
# 0.9792034423678584
